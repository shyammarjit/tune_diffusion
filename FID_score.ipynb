# %%
from datasets import load_dataset

ds = load_dataset("lambdalabs/pokemon-blip-captions", split="train")

text_array = []  # Array to store the "text" values

for i in range(len(ds)):
    sample = ds[i]
    text_array.append(sample["text"])
    print(sample["text"])

# Printing the resulting array
# Out:
# Found cached dataset parquet (/home/btech/ayush.singh/.cache/huggingface/datasets/lambdalabs___parquet/lambdalabs--pokemon-blip-captions-10e3527a764857bd/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# a drawing of a green pokemon with red eyes
# a green and yellow toy with a red nose
# a red and white ball with an angry look on its face
# a cartoon ball with a smile on it's face
# a bunch of balls with faces drawn on them
# a cartoon character with a potted plant on his head
# a drawing of a pokemon stuffed animal
# a picture of a cartoon character with a sword
# a drawing of a cartoon character doing a kick
# a drawing of a girl with a boxing glove
# a picture of a pink and yellow pokemon figure
# a purple ball with a skull and cross bones on it
# a cartoon picture of a green vegetable with eyes
# an image of a cartoon character flying through the air
# a drawing of a gray and black dragon
# a drawing of a gray and yellow pokemon
# ...

# %%
text_array

# %%
# krona 2 with datas
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/datas /home/btech/ayush.singh/tune_diffusion/training_scripts/krona_images_4
# Out:
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:01<00:00,  1.90it/s]
# FID:  125.92270827742968

# %%
# kron 2
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/orignal_images /home/btech/ayush.singh/tune_diffusion/training_scripts/krona_images_2
# Out:
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.02it/s]
# FID:  114.27488343537146

# %%
# krona 4 with datas
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/datas /home/btech/ayush.singh/tune_diffusion/training_scripts/krona_images_2
# Out:
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.00it/s]
# FID:  126.65364250939248

# %%
# krona 4
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/orignal_images /home/btech/ayush.singh/tune_diffusion/training_scripts/krona_images_4
# Out:
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:01<00:00,  1.21it/s]
# FID:  111.42450961910723

# %%
# lora with datas
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/datas /home/btech/ayush.singh/tune_diffusion/training_scripts/lora_images
# Out:
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00,  2.05it/s]
# FID:  157.66248039381134

# %%
# lora 
# !python -m pytorch_fid /home/btech/ayush.singh/tune_diffusion/training_scripts/orignal_images /home/btech/ayush.singh/tune_diffusion/training_scripts/lora_images
# Out:
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:04<00:00,  2.04s/it]
# FID:  116.73036376097829

# %%
# orgnal with datas
# !python -m pytorch_fid  /home/btech/ayush.singh/tune_diffusion/training_scripts/datas /home/btech/ayush.singh/tune_diffusion/training_scripts/orignal_images
# Out:
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# FID:  157.72795316041274

# %%
# !python -m pytorch_fid /home/btech/ayush.singh/tune_diffusion/training_scripts/krona_images_4 /home/btech/ayush.singh/tune_diffusion/training_scripts/lora_images
# Out:
# ...
# 100%|█████████████████████████████████████████████| 2/2 [00:01<00:00,  1.21it/s]
# FID:  99.4105119149124

# %%
# !python -m pytorch_fid /home/btech/ayush.singh/tune_diffusion/training_scripts/output_krona_16 /home/btech/ayush.singh/tune_diffusion/training_scripts/output_krona_32
# Out:
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# FID:  147.63971984738436

# %%
fid = fid_score.calculate_fid_given_paths(real_images, fake_images)

print(fid)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 fid = fid_score.calculate_fid_given_paths(real_images, fake_images)
#       3 print(fid)
#
# TypeError: calculate_fid_given_paths() missing 2 required positional arguments: 'device' and 'dims'

# %%
from torchmetrics.image.fid import FrechetInceptionDistance

fid = FrechetInceptionDistance(normalize=True)
fid.update(real_images, real=True)
fid.update(fake_images, real=False)

print(f"FID: {float(fid.compute())}")
# FID: 177.7147216796875
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 3
#       1 from torchmetrics.image.fid import FrechetInceptionDistance
# ----> 3 fid = FrechetInceptionDistance(normalize=True)
#       4 fid.update(real_images, real=True)
#       5 fid.update(fake_images, real=False)
#
# File ~/miniconda3/envs/loras/lib/python3.10/site-packages/torchmetrics/image/fid.py:225, in FrechetInceptionDistance.__init__(self, feature, reset_real_features, normalize, **kwargs)
#     223 num_features = feature
#     224 if not _TORCH_FIDELITY_AVAILABLE:
# --> 225     raise ModuleNotFoundError(
#     226         "FrechetInceptionDistance metric requires that `Torch-fidelity` is installed."
#     227         " Either install as `pip install torchmetrics[image]` or `pip install torch-fidelity`."
#     228     )
#     229 valid_int_input = [64, 192, 768, 2048]
# ...

# %%
# !python -m pytorch_fid /home/btech/ayush.singh/tune_diffusion/training_scripts/output_krona_16 /home/btech/ayush.singh/tune_diffusion/training_scripts/output_krona_16
# Out:
# ...
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.48s/it]
# FID:  -0.00021772937833475225

# %%
# OFFICIAL CODE


class_ids = dit_pipeline.get_label_ids(words)
output = dit_pipeline(class_labels=class_ids, generator=generator, output_type="numpy")

fake_images = output.images
fake_images = torch.tensor(fake_images)
fake_images = fake_images.permute(0, 3, 1, 2)
print(fake_images.shape)
# torch.Size([10, 3, 256, 256])


from torchmetrics.image.fid import FrechetInceptionDistance

fid = FrechetInceptionDistance(normalize=True)
fid.update(real_images, real=True)
fid.update(fake_images, real=False)

print(f"FID: {float(fid.compute())}")
# FID: 177.7147216796875
